# %% [markdown]
# ### Data Variables

# %%
from pandas import (
    DataFrame,
    set_option, reset_option,
)

from contest.data import describe
from contest.exploration.descriptions.vars import describe as describe_vars
from contest.exploration.descriptions.categoricals import describe as describe_categoricals

def set_display_options(
    dataframe: DataFrame
):
     set_option(
        'display.max_rows', dataframe.shape[0],
        'display.max_columns', dataframe.shape[1],
        # 'display.max_colwidth', None,
    )

        
def reset_display_options():
    reset_option('display.*')

# %% [markdown]
# #### All variables

# %%
data_description = describe_vars()

# %%
# set_display_options(data_description)

data_description
# Out:
#                                                     description  \
# variable
# MSSubClass    Identifies the type of dwelling involved in th...
# MSZoning      Identifies the general zoning classification o...
# LotFrontage         Linear feet of street connected to property
# LotArea                                 Lot size in square feet
# Street                          Type of road access to property
# Alley                          Type of alley access to property
# LotShape                              General shape of property
# LandContour                            Flatness of the property
# Utilities                           Type of utilities available
# LotConfig                                     Lot configuration
# LandSlope                                     Slope of property
# Neighborhood         Physical locations within Ames city limits
# Condition1                      Proximity to various conditions
# ...

# %%
# reset_display_options()

# %% [markdown]
# #### Categorical

# %%
data_description = describe_categoricals()

# %%
# set_display_options(data_description)

data_description
# Out:
#                                                     description  \
# variable
# MSSubClass    Identifies the type of dwelling involved in th...
# MSZoning      Identifies the general zoning classification o...
# Street                          Type of road access to property
# Alley                          Type of alley access to property
# LotShape                              General shape of property
# LandContour                            Flatness of the property
# Utilities                           Type of utilities available
# LotConfig                                     Lot configuration
# LandSlope                                     Slope of property
# Neighborhood         Physical locations within Ames city limits
# Condition1                      Proximity to various conditions
# Condition2    Proximity to various conditions (if more than ...
# BldgType                                       Type of dwelling
# ...

# %%
# reset_display_options()

# %% [markdown]
# ##### Nominal

# %%
# var_type = ('categorical', 'nominal')
var_type = 'nominal'

data_description = describe(var_type=var_type)

# %%
# set_display_options(data_description)

data_description
# Out:
#                                                     description  \
# variable
# MSSubClass    Identifies the type of dwelling involved in th...
# MSZoning      Identifies the general zoning classification o...
# Street                          Type of road access to property
# Alley                          Type of alley access to property
# LotShape                              General shape of property
# LandContour                            Flatness of the property
# LotConfig                                     Lot configuration
# LandSlope                                     Slope of property
# Neighborhood         Physical locations within Ames city limits
# Condition1                      Proximity to various conditions
# Condition2    Proximity to various conditions (if more than ...
# BldgType                                       Type of dwelling
# HouseStyle                                    Style of dwelling
# ...

# %%
# reset_display_options()

# %% [markdown]
# ##### Ordinal

# %%
# var_type = ('categorical', 'ordinal')
var_type = 'ordinal'

data_description = describe(var_type=var_type)

# %%
# set_display_options(data_description)

data_description
# Out:
#                                                     description  \
# variable
# Utilities                           Type of utilities available
# OverallQual   Rates the overall material and finish of the h...
# OverallCond            Rates the overall condition of the house
# ExterQual     Evaluates the quality of the material on the e...
# ExterCond     Evaluates the present condition of the materia...
# BsmtQual                   Evaluates the height of the basement
# BsmtCond        Evaluates the general condition of the basement
# BsmtExposure            Refers to walkout or garden level walls
#
#                                 type  \
# variable
# Utilities     (categorical, ordinal)
# OverallQual   (categorical, ordinal)
# OverallCond   (categorical, ordinal)
# ExterQual     (categorical, ordinal)
# ExterCond     (categorical, ordinal)
# BsmtQual      (categorical, ordinal)
# BsmtCond      (categorical, ordinal)
# BsmtExposure  (categorical, ordinal)
#
# ...

# %%
# reset_display_options()

# %% [markdown]
# ##### Date

# %%
# var_type = ('categorical', 'date')
var_type = 'date'

data_description = describe(var_type=var_type)

# %%
# set_display_options(data_description)

data_description
# Out:
#                                                     description  \
# variable
# YearBuilt                            Original construction date
# YearRemodAdd  Remodel date (same as construction date if no ...
#
#                              type categories scales
# variable
# YearBuilt     (categorical, date)        NaN    NaN
# YearRemodAdd  (categorical, date)        NaN    NaN

# %%
# reset_display_options()

# %% [markdown]
# #### Numerical

# %%
var_type = 'numerical'

data_description = describe(var_type=var_type)

# %%
# set_display_options(data_description)

data_description
# Out:
#                                              description  \
# variable
# LotFrontage  Linear feet of street connected to property
# LotArea                          Lot size in square feet
# MasVnrArea            Masonry veneer area in square feet
#
#                                 type categories scales
# variable
# LotFrontage  (numerical, continuous)        NaN    NaN
# LotArea      (numerical, continuous)        NaN    NaN
# MasVnrArea   (numerical, continuous)        NaN    NaN

# %%
# reset_display_options()

# %% [markdown]
# ##### Continuous

# %%
# var_type = ('numerical', 'continuous')
var_type = 'continuous'


data_description = describe(var_type=var_type)

# %%
# set_display_options(data_description)

data_description
# Out:
#                                              description  \
# variable
# LotFrontage  Linear feet of street connected to property
# LotArea                          Lot size in square feet
# MasVnrArea            Masonry veneer area in square feet
#
#                                 type categories scales
# variable
# LotFrontage  (numerical, continuous)        NaN    NaN
# LotArea      (numerical, continuous)        NaN    NaN
# MasVnrArea   (numerical, continuous)        NaN    NaN
