# %% [markdown]
# ### Datasets Description: Train, Test

# %%
from pandas import set_option, reset_option

from contest.data.sets import load
from contest.data.descriptors import DataDescriptor

set_option(
    'display.max_rows', None,
    'display.max_columns', None,
)

# %% [markdown]
# #### Load

# %%
keys = ['train', 'test']

data = load(keys, info=True)
descriptor = DataDescriptor(data)
# Out:
# train: train.csv
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# #### Types

# %%
descriptor.types(transformers=True)
# Out:
# dataset                                                    train  test
#                                              detect nulls
# shape rows                                                  1460  1459
#       columns                                                 80    79
#                                              False            61    46
#                                              True             19    33
# type  <class 'object'>                                        43    43
#                                              False            27    21
#                                              True             16    22
#       <class 'numpy.number'>                                  37    36
#                                              False            34    25
#                                              True              3    11
#                              <class 'int'>                    34    25
# ...

# %% [markdown]
# #### Nulls

# %%
descriptor.nulls(transformers=True)
# Out:
#                  type          counts                                  \
#                                              null       notnull
# dataset         train     test  train  test train  test   train  test
# variable
# BsmtFinSF1      int64  float64   1460  1459     0     1    1460  1458
# BsmtFinSF2      int64  float64   1460  1459     0     1    1460  1458
# BsmtUnfSF       int64  float64   1460  1459     0     1    1460  1458
# TotalBsmtSF     int64  float64   1460  1459     0     1    1460  1458
# GarageCars      int64  float64   1460  1459     0     1    1460  1458
# GarageArea      int64  float64   1460  1459     0     1    1460  1458
# Exterior1st    object   object   1460  1459     0     1    1460  1458
# Exterior2nd    object   object   1460  1459     0     1    1460  1458
# KitchenQual    object   object   1460  1459     0     1    1460  1458
# SaleType       object   object   1460  1459     0     1    1460  1458
# ...

# %% [markdown]
# #### Uniques

# %%
descriptor.uniques(transformers=True)
# Out:
#                   type          counts                                   \
#                                              non-null        null
# include nulls
# dataset          train     test  train  test    train  test train  test
# variable
# Utilities       object   object   1460  1459     1460  1457     0     2
# Street          object   object   1460  1459     1460  1459     0     0
# CentralAir      object   object   1460  1459     1460  1459     0     0
# Alley           object   object   1460  1459       91   107  1369  1352
# HalfBath         int64    int64   1460  1459     1460  1459     0     0
# LandSlope       object   object   1460  1459     1460  1459     0     0
# PavedDrive      object   object   1460  1459     1460  1459     0     0
# BsmtHalfBath     int64  float64   1460  1459     1460  1457     0     2
# PoolQC          object   object   1460  1459        7     3  1453  1456
# KitchenAbvGr     int64    int64   1460  1459     1460  1459     0     0
# ...

# %%
reset_option('display.*')
