# %% [markdown]
# ### Single set: train

# %%
from numpy import number
from pandas import set_option, reset_option

from contest.data import load
from contest.exploration.tools import describe, transform, sample
from contest.exploration.descriptions.types import single_describe_params as types_describe_params
from contest.exploration.descriptions.objects import transform_transformers as objects_transform_transformers
from contest.exploration.descriptions.numbers import transform_transformers as numbers_transform_transformers
from contest.exploration.descriptions.nulls import single_describe_params as nulls_describe_params
from contest.exploration.descriptions.uniques import single_describe_params as uniques_describe_params
from contest.exploration.descriptions.sample import transform_transformers as sample_transform_transformers

# %% [markdown]
# #### Load

# %%
data_key = 'train'

data_set = load(
    data_keys=data_key,
    print_info=True,
)
# Out:
# train: train.csv
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     1452 non-null   object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
#  79  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 923.9+ KB

# %% [markdown]
# #### Types

# %%
types_description = describe(
    data=data_set,
    **types_describe_params
)

# %%
# set_option('display.max_row', len(types_description))

types_description
# Out:
#                                                 detect nulls
# shape  rows                                                     1460
#        columns                                                    80
#                                                 False             61
#                                                 True              19
# type   <class 'object'>                                           43
#                                                 False             27
#                                                 True              16
#        <class 'numpy.number'>                                     37
#                                                 False             34
#                                                 True               3
#                                <class 'int'>                      34
#                                                 False             34
#                                                 True               0
#                                <class 'float'>                     3
#                                                 False              0
#                                                 True               3
# dtype: int64

# %%
# reset_option('display.*')

# %% [markdown]
# ##### Objects

# %%
data_type = object

objects_description = transform(
    data=data_set.select_dtypes(data_type).describe(),
    transformers=objects_transform_transformers,
)

# %%
# set_option(
#     'display.max_rows', objects_description.shape[0],
#     'display.max_columns', objects_description.shape[1],
# )

objects_description
# Out:
#                  count unique      top  freq
#    variable
# 1  Street         1460      2     Pave  1454
# 2  Utilities      1460      2   AllPub  1459
# 3  CentralAir     1460      2        Y  1365
# 4  Alley            91      2     Grvl    50
# 5  LandSlope      1460      3      Gtl  1382
# 6  PavedDrive     1460      3        Y  1340
# 7  GarageFinish   1379      3      Unf   605
# 8  PoolQC            7      3       Gd     3
# 9  LotShape       1460      4      Reg   925
# 10 LandContour    1460      4      Lvl  1311
# 11 ExterQual      1460      4       TA   906
# 12 KitchenQual    1460      4       TA   735
# 13 MasVnrType     1452      4     None   864
# 14 BsmtQual       1423      4       TA   649
# 15 BsmtCond       1423      4       TA  1311
# 16 BsmtExposure   1422      4       No   953
# 17 Fence           281      4    MnPrv   157
# 18 MiscFeature      54      4     Shed    49
# 19 MSZoning       1460      5       RL  1151
# 20 LotConfig      1460      5   Inside  1052
# 21 BldgType       1460      5     1Fam  1220
# 22 ExterCond      1460      5       TA  1282
# 23 HeatingQC      1460      5       Ex   741
# 24 Electrical     1459      5    SBrkr  1334
# 25 GarageQual     1379      5       TA  1311
# 26 GarageCond     1379      5       TA  1326
# 27 FireplaceQu     770      5       Gd   380
# 28 RoofStyle      1460      6    Gable  1141
# 29 Foundation     1460      6    PConc   647
# 30 Heating        1460      6     GasA  1428
# 31 SaleCondition  1460      6   Normal  1198
# 32 BsmtFinType1   1423      6      Unf   430
# 33 BsmtFinType2   1422      6      Unf  1256
# 34 GarageType     1379      6   Attchd   870
# 35 Functional     1460      7      Typ  1360
# 36 Condition2     1460      8     Norm  1445
# 37 HouseStyle     1460      8   1Story   726
# 38 RoofMatl       1460      8  CompShg  1434
# 39 Condition1     1460      9     Norm  1260
# 40 SaleType       1460      9       WD  1267
# 41 Exterior1st    1460     15  VinylSd   515
# 42 Exterior2nd    1460     16  VinylSd   504
# 43 Neighborhood   1460     25    NAmes   225

# %%
# reset_option('display.*')

# %% [markdown]
# ##### Numbers

# %%
data_type = number

numbers_description = transform(
    data=data_set.select_dtypes(data_type).describe(),
    transformers=numbers_transform_transformers,
)

# %%
# set_option(
#     'display.max_rows', numbers_description.shape[0],
#     'display.max_columns', numbers_description.shape[1],
# )

numbers_description
# Out:
#                    count           mean           std      min        25%  \
#    variable
# 1  MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# 2  LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# 3  LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# 4  OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# 5  OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# 6  YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# 7  YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# 8  MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# 9  BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# 10 BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# 11 BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# 12 TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 13 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 14 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# 15 LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.00
# 16 GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# 17 BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# 18 BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.00
# 19 FullBath       1460.0       1.565068      0.550916      0.0       1.00
# 20 HalfBath       1460.0       0.382877      0.502885      0.0       0.00
# 21 BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# 22 KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# 23 TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       5.00
# 24 Fireplaces     1460.0       0.613014      0.644666      0.0       0.00
# 25 GarageYrBlt    1379.0    1978.506164     24.689725   1900.0    1961.00
# 26 GarageCars     1460.0       1.767123      0.747315      0.0       1.00
# 27 GarageArea     1460.0     472.980137    213.804841      0.0     334.50
# 28 WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.00
# 29 OpenPorchSF    1460.0      46.660274     66.256028      0.0       0.00
# 30 EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.00
# 31 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.00
# 32 ScreenPorch    1460.0      15.060959     55.757415      0.0       0.00
# 33 PoolArea       1460.0       2.758904     40.177307      0.0       0.00
# 34 MiscVal        1460.0      43.489041    496.123024      0.0       0.00
# 35 MoSold         1460.0       6.321918      2.703626      1.0       5.00
# 36 YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
# 37 SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                        50%        75%       max
#    variable
# 1  MSSubClass         50.0      70.00     190.0
# 2  LotFrontage        69.0      80.00     313.0
# 3  LotArea          9478.5   11601.50  215245.0
# 4  OverallQual         6.0       7.00      10.0
# 5  OverallCond         5.0       6.00       9.0
# 6  YearBuilt        1973.0    2000.00    2010.0
# 7  YearRemodAdd     1994.0    2004.00    2010.0
# 8  MasVnrArea          0.0     166.00    1600.0
# 9  BsmtFinSF1        383.5     712.25    5644.0
# 10 BsmtFinSF2          0.0       0.00    1474.0
# 11 BsmtUnfSF         477.5     808.00    2336.0
# 12 TotalBsmtSF       991.5    1298.25    6110.0
# 13 1stFlrSF         1087.0    1391.25    4692.0
# 14 2ndFlrSF            0.0     728.00    2065.0
# 15 LowQualFinSF        0.0       0.00     572.0
# 16 GrLivArea        1464.0    1776.75    5642.0
# 17 BsmtFullBath        0.0       1.00       3.0
# 18 BsmtHalfBath        0.0       0.00       2.0
# 19 FullBath            2.0       2.00       3.0
# 20 HalfBath            0.0       1.00       2.0
# 21 BedroomAbvGr        3.0       3.00       8.0
# 22 KitchenAbvGr        1.0       1.00       3.0
# 23 TotRmsAbvGrd        6.0       7.00      14.0
# 24 Fireplaces          1.0       1.00       3.0
# 25 GarageYrBlt      1980.0    2002.00    2010.0
# 26 GarageCars          2.0       2.00       4.0
# 27 GarageArea        480.0     576.00    1418.0
# 28 WoodDeckSF          0.0     168.00     857.0
# 29 OpenPorchSF        25.0      68.00     547.0
# 30 EnclosedPorch       0.0       0.00     552.0
# 31 3SsnPorch           0.0       0.00     508.0
# 32 ScreenPorch         0.0       0.00     480.0
# 33 PoolArea            0.0       0.00     738.0
# 34 MiscVal             0.0       0.00   15500.0
# 35 MoSold              6.0       8.00      12.0
# 36 YrSold           2008.0    2009.00    2010.0
# 37 SalePrice      163000.0  214000.00  755000.0

# %%
# reset_option('display.*')

# %% [markdown]
# #### Nulls

# %%
nulls_description = describe(
    data=data_set,
    **nulls_describe_params
)

# %%
# set_option(
#     'display.max_rows', nulls_description.shape[0],
#     'display.max_columns', nulls_description.shape[1],
# )

nulls_description
# Out:
#                     type counts                 portion
#                                  null notnull      null   notnull
#    variable
# 1  Electrical     object   1460     1    1459  0.000685  0.999315
# 2  MasVnrArea    float64   1460     8    1452  0.005479  0.994521
# 3  MasVnrType     object   1460     8    1452  0.005479  0.994521
# 4  BsmtQual       object   1460    37    1423  0.025342  0.974658
# 5  BsmtCond       object   1460    37    1423  0.025342  0.974658
# 6  BsmtFinType1   object   1460    37    1423  0.025342  0.974658
# 7  BsmtExposure   object   1460    38    1422  0.026027  0.973973
# 8  BsmtFinType2   object   1460    38    1422  0.026027  0.973973
# 9  GarageYrBlt   float64   1460    81    1379  0.055479  0.944521
# 10 GarageType     object   1460    81    1379  0.055479  0.944521
# 11 GarageFinish   object   1460    81    1379  0.055479  0.944521
# 12 GarageQual     object   1460    81    1379  0.055479  0.944521
# 13 GarageCond     object   1460    81    1379  0.055479  0.944521
# 14 LotFrontage   float64   1460   259    1201  0.177397  0.822603
# 15 FireplaceQu    object   1460   690     770  0.472603  0.527397
# 16 Fence          object   1460  1179     281  0.807534  0.192466
# 17 Alley          object   1460  1369      91  0.937671  0.062329
# 18 MiscFeature    object   1460  1406      54  0.963014  0.036986
# 19 PoolQC         object   1460  1453       7  0.995205  0.004795

# %%
# reset_option('display.*')

# %% [markdown]
# #### Uniques

# %%
uniques_description = describe(
    data=data_set,
    **uniques_describe_params
)

# %%
set_option(
    'display.max_rows', uniques_description.shape[0],
    # 'display.max_columns', uniques_description.shape[1],
)

uniques_description
# Out:
#                      type counts                unique                  \
#                                  non-null  null counts           ratio
# include nulls                                     True False      True
#    variable
# 1  Street          object   1460     1460     0      2     2  0.001370
# 2  Utilities       object   1460     1460     0      2     2  0.001370
# 3  CentralAir      object   1460     1460     0      2     2  0.001370
# 4  Alley           object   1460       91  1369      3     2  0.002055
# 5  BsmtHalfBath     int64   1460     1460     0      3     3  0.002055
# 6  HalfBath         int64   1460     1460     0      3     3  0.002055
# 7  LandSlope       object   1460     1460     0      3     3  0.002055
# 8  PavedDrive      object   1460     1460     0      3     3  0.002055
# 9  GarageFinish    object   1460     1379    81      4     3  0.002740
# 10 PoolQC          object   1460        7  1453      4     3  0.002740
# 11 BsmtFullBath     int64   1460     1460     0      4     4  0.002740
# 12 FullBath         int64   1460     1460     0      4     4  0.002740
# 13 KitchenAbvGr     int64   1460     1460     0      4     4  0.002740
# 14 Fireplaces       int64   1460     1460     0      4     4  0.002740
# 15 LotShape        object   1460     1460     0      4     4  0.002740
# 16 LandContour     object   1460     1460     0      4     4  0.002740
# 17 ExterQual       object   1460     1460     0      4     4  0.002740
# 18 KitchenQual     object   1460     1460     0      4     4  0.002740
# 19 MasVnrType      object   1460     1452     8      5     4  0.003425
# 20 BsmtQual        object   1460     1423    37      5     4  0.003425
# 21 BsmtCond        object   1460     1423    37      5     4  0.003425
# 22 BsmtExposure    object   1460     1422    38      5     4  0.003425
# 23 Fence           object   1460      281  1179      5     4  0.003425
# 24 MiscFeature     object   1460       54  1406      5     4  0.003425
# 25 GarageCars       int64   1460     1460     0      5     5  0.003425
# 26 YrSold           int64   1460     1460     0      5     5  0.003425
# 27 MSZoning        object   1460     1460     0      5     5  0.003425
# 28 LotConfig       object   1460     1460     0      5     5  0.003425
# 29 BldgType        object   1460     1460     0      5     5  0.003425
# 30 ExterCond       object   1460     1460     0      5     5  0.003425
# 31 HeatingQC       object   1460     1460     0      5     5  0.003425
# 32 Electrical      object   1460     1459     1      6     5  0.004110
# 33 GarageQual      object   1460     1379    81      6     5  0.004110
# 34 GarageCond      object   1460     1379    81      6     5  0.004110
# 35 FireplaceQu     object   1460      770   690      6     5  0.004110
# 36 RoofStyle       object   1460     1460     0      6     6  0.004110
# 37 Foundation      object   1460     1460     0      6     6  0.004110
# 38 Heating         object   1460     1460     0      6     6  0.004110
# 39 SaleCondition   object   1460     1460     0      6     6  0.004110
# 40 BsmtFinType1    object   1460     1423    37      7     6  0.004795
# 41 BsmtFinType2    object   1460     1422    38      7     6  0.004795
# 42 GarageType      object   1460     1379    81      7     6  0.004795
# 43 Functional      object   1460     1460     0      7     7  0.004795
# 44 BedroomAbvGr     int64   1460     1460     0      8     8  0.005479
# 45 PoolArea         int64   1460     1460     0      8     8  0.005479
# 46 Condition2      object   1460     1460     0      8     8  0.005479
# 47 HouseStyle      object   1460     1460     0      8     8  0.005479
# 48 RoofMatl        object   1460     1460     0      8     8  0.005479
# 49 OverallCond      int64   1460     1460     0      9     9  0.006164
# 50 Condition1      object   1460     1460     0      9     9  0.006164
# 51 SaleType        object   1460     1460     0      9     9  0.006164
# 52 OverallQual      int64   1460     1460     0     10    10  0.006849
# 53 TotRmsAbvGrd     int64   1460     1460     0     12    12  0.008219
# 54 MoSold           int64   1460     1460     0     12    12  0.008219
# 55 MSSubClass       int64   1460     1460     0     15    15  0.010274
# 56 Exterior1st     object   1460     1460     0     15    15  0.010274
# 57 Exterior2nd     object   1460     1460     0     16    16  0.010959
# 58 3SsnPorch        int64   1460     1460     0     20    20  0.013699
# 59 MiscVal          int64   1460     1460     0     21    21  0.014384
# 60 LowQualFinSF     int64   1460     1460     0     24    24  0.016438
# 61 Neighborhood    object   1460     1460     0     25    25  0.017123
# 62 YearRemodAdd     int64   1460     1460     0     61    61  0.041781
# 63 ScreenPorch      int64   1460     1460     0     76    76  0.052055
# 64 GarageYrBlt    float64   1460     1379    81     98    97  0.067123
# 65 LotFrontage    float64   1460     1201   259    111   110  0.076027
# 66 YearBuilt        int64   1460     1460     0    112   112  0.076712
# 67 EnclosedPorch    int64   1460     1460     0    120   120  0.082192
# 68 BsmtFinSF2       int64   1460     1460     0    144   144  0.098630
# 69 OpenPorchSF      int64   1460     1460     0    202   202  0.138356
# 70 WoodDeckSF       int64   1460     1460     0    274   274  0.187671
# 71 MasVnrArea     float64   1460     1452     8    328   327  0.224658
# 72 2ndFlrSF         int64   1460     1460     0    417   417  0.285616
# 73 GarageArea       int64   1460     1460     0    441   441  0.302055
# 74 BsmtFinSF1       int64   1460     1460     0    637   637  0.436301
# 75 SalePrice        int64   1460     1460     0    663   663  0.454110
# 76 TotalBsmtSF      int64   1460     1460     0    721   721  0.493836
# 77 1stFlrSF         int64   1460     1460     0    753   753  0.515753
# 78 BsmtUnfSF        int64   1460     1460     0    780   780  0.534247
# 79 GrLivArea        int64   1460     1460     0    861   861  0.589726
# 80 LotArea          int64   1460     1460     0   1073  1073  0.734932
#
#
#
# include nulls        False
#    variable
# 1  Street         0.001370
# 2  Utilities      0.001370
# 3  CentralAir     0.001370
# 4  Alley          0.021978
# 5  BsmtHalfBath   0.002055
# 6  HalfBath       0.002055
# 7  LandSlope      0.002055
# 8  PavedDrive     0.002055
# 9  GarageFinish   0.002175
# 10 PoolQC         0.428571
# 11 BsmtFullBath   0.002740
# 12 FullBath       0.002740
# 13 KitchenAbvGr   0.002740
# 14 Fireplaces     0.002740
# 15 LotShape       0.002740
# 16 LandContour    0.002740
# 17 ExterQual      0.002740
# 18 KitchenQual    0.002740
# 19 MasVnrType     0.002755
# 20 BsmtQual       0.002811
# 21 BsmtCond       0.002811
# 22 BsmtExposure   0.002813
# 23 Fence          0.014235
# 24 MiscFeature    0.074074
# 25 GarageCars     0.003425
# 26 YrSold         0.003425
# 27 MSZoning       0.003425
# 28 LotConfig      0.003425
# 29 BldgType       0.003425
# 30 ExterCond      0.003425
# 31 HeatingQC      0.003425
# 32 Electrical     0.003427
# 33 GarageQual     0.003626
# 34 GarageCond     0.003626
# 35 FireplaceQu    0.006494
# 36 RoofStyle      0.004110
# 37 Foundation     0.004110
# 38 Heating        0.004110
# 39 SaleCondition  0.004110
# 40 BsmtFinType1   0.004216
# 41 BsmtFinType2   0.004219
# 42 GarageType     0.004351
# 43 Functional     0.004795
# 44 BedroomAbvGr   0.005479
# 45 PoolArea       0.005479
# 46 Condition2     0.005479
# 47 HouseStyle     0.005479
# 48 RoofMatl       0.005479
# 49 OverallCond    0.006164
# 50 Condition1     0.006164
# 51 SaleType       0.006164
# 52 OverallQual    0.006849
# 53 TotRmsAbvGrd   0.008219
# 54 MoSold         0.008219
# 55 MSSubClass     0.010274
# 56 Exterior1st    0.010274
# 57 Exterior2nd    0.010959
# 58 3SsnPorch      0.013699
# 59 MiscVal        0.014384
# 60 LowQualFinSF   0.016438
# 61 Neighborhood   0.017123
# 62 YearRemodAdd   0.041781
# 63 ScreenPorch    0.052055
# 64 GarageYrBlt    0.070341
# 65 LotFrontage    0.091590
# 66 YearBuilt      0.076712
# 67 EnclosedPorch  0.082192
# 68 BsmtFinSF2     0.098630
# 69 OpenPorchSF    0.138356
# 70 WoodDeckSF     0.187671
# 71 MasVnrArea     0.225207
# 72 2ndFlrSF       0.285616
# 73 GarageArea     0.302055
# 74 BsmtFinSF1     0.436301
# 75 SalePrice      0.454110
# 76 TotalBsmtSF    0.493836
# 77 1stFlrSF       0.515753
# 78 BsmtUnfSF      0.534247
# 79 GrLivArea      0.589726
# 80 LotArea        0.734932

# %%
reset_option('display.*')

# %% [markdown]
# #### Sample

# %%
n = 3, 6, 3

data_sample = transform(
    data=sample(
        data=load(data_keys=data_key),
        n=n,
    ),
    transformers=sample_transform_transformers
)

# %%
set_option(
    'display.max_rows', data_sample.shape[0],
    # 'display.max_columns', data_sample.shape[1],
)
    
data_sample
# Out:
# id                   1        2        3        130      166      883   \
#    variable
# 1  MSSubClass          60       20       60       20      190       60
# 2  MSZoning            RL       RL       RL       RL       RL       RL
# 3  LotFrontage       65.0     80.0     68.0     69.0     62.0      NaN
# 4  LotArea           8450     9600    11250     8973    10106     9636
# 5  Street            Pave     Pave     Pave     Pave     Pave     Pave
# 6  Alley              NaN      NaN      NaN      NaN      NaN      NaN
# 7  LotShape           Reg      Reg      IR1      Reg      Reg      IR1
# 8  LandContour        Lvl      Lvl      Lvl      Lvl      Lvl      Lvl
# 9  Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# 10 LotConfig       Inside      FR2   Inside   Inside   Inside   Corner
# 11 LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl      Gtl
# 12 Neighborhood   CollgCr  Veenker  CollgCr    NAmes  Edwards  Gilbert
# 13 Condition1        Norm    Feedr     Norm     Norm     Norm     Norm
# 14 Condition2        Norm     Norm     Norm     Norm     Norm     Norm
# 15 BldgType          1Fam     1Fam     1Fam     1Fam   2fmCon     1Fam
# 16 HouseStyle      2Story   1Story   2Story   1Story   1.5Fin   2Story
# 17 OverallQual          7        6        7        5        5        6
# 18 OverallCond          5        8        5        7        7        5
# 19 YearBuilt         2003     1976     2001     1958     1940     1992
# 20 YearRemodAdd      2003     1976     2002     1991     1999     1993
# 21 RoofStyle        Gable    Gable    Gable    Gable    Gable    Gable
# 22 RoofMatl       CompShg  CompShg  CompShg  CompShg  CompShg  CompShg
# 23 Exterior1st    VinylSd  MetalSd  VinylSd  Plywood  Wd Sdng  VinylSd
# 24 Exterior2nd    VinylSd  MetalSd  VinylSd  Plywood  Wd Sdng  VinylSd
# 25 MasVnrType     BrkFace     None  BrkFace  BrkFace     None     None
# 26 MasVnrArea       196.0      0.0    162.0     85.0      0.0      0.0
# 27 ExterQual           Gd       TA       Gd       TA       TA       TA
# 28 ExterCond           TA       TA       TA       TA       Gd       TA
# 29 Foundation       PConc   CBlock    PConc   CBlock   BrkTil    PConc
# 30 BsmtQual            Gd       Gd       Gd       TA       TA       Gd
# 31 BsmtCond            TA       TA       TA       TA       TA       TA
# 32 BsmtExposure        No       Gd       Mn       No       No       No
# 33 BsmtFinType1       GLQ      ALQ      GLQ      Rec      ALQ      Unf
# 34 BsmtFinSF1         706      978      486      567      351        0
# 35 BsmtFinType2       Unf      Unf      Unf      BLQ      Rec      Unf
# 36 BsmtFinSF2           0        0        0       28      181        0
# 37 BsmtUnfSF          150      284      434      413      112      808
# 38 TotalBsmtSF        856     1262      920     1008      644      808
# 39 Heating           GasA     GasA     GasA     GasA     GasA     GasA
# 40 HeatingQC           Ex       Ex       Ex       TA       Gd       Gd
# 41 CentralAir           Y        Y        Y        Y        Y        Y
# 42 Electrical       SBrkr    SBrkr    SBrkr    FuseA    SBrkr    SBrkr
# 43 1stFlrSF           856     1262      920     1053      808      808
# 44 2ndFlrSF           854        0      866        0      547      785
# 45 LowQualFinSF         0        0        0        0        0        0
# 46 GrLivArea         1710     1262     1786     1053     1355     1593
# 47 BsmtFullBath         1        0        1        0        1        0
# 48 BsmtHalfBath         0        1        0        1        0        0
# 49 FullBath             2        2        2        1        2        2
# 50 HalfBath             1        0        1        1        0        1
# 51 BedroomAbvGr         3        3        3        3        4        3
# 52 KitchenAbvGr         1        1        1        1        2        1
# 53 KitchenQual         Gd       TA       Gd       Ex       TA       TA
# 54 TotRmsAbvGrd         8        6        6        6        6        7
# 55 Functional         Typ      Typ      Typ      Typ      Typ      Typ
# 56 Fireplaces           0        1        1        0        0        1
# 57 FireplaceQu        NaN       TA       TA      NaN      NaN       TA
# 58 GarageType      Attchd   Attchd   Attchd   2Types      NaN  BuiltIn
# 59 GarageYrBlt     2003.0   1976.0   2001.0   1998.0      NaN   1993.0
# 60 GarageFinish       RFn      RFn      RFn      RFn      NaN      RFn
# 61 GarageCars           2        2        2        2        0        2
# 62 GarageArea         548      460      608      750        0      389
# 63 GarageQual          TA       TA       TA       TA      NaN       TA
# 64 GarageCond          TA       TA       TA       TA      NaN       TA
# 65 PavedDrive           Y        Y        Y        Y        Y        Y
# 66 WoodDeckSF           0      298        0        0      140      342
# 67 OpenPorchSF         61        0       42       80        0       40
# 68 EnclosedPorch        0        0        0        0        0        0
# 69 3SsnPorch            0        0        0      180        0        0
# 70 ScreenPorch          0        0        0        0        0        0
# 71 PoolArea             0        0        0        0        0        0
# 72 PoolQC             NaN      NaN      NaN      NaN      NaN      NaN
# 73 Fence              NaN      NaN      NaN     MnWw      NaN    MnPrv
# 74 MiscFeature        NaN      NaN      NaN      NaN      NaN      NaN
# 75 MiscVal              0        0        0        0        0        0
# 76 MoSold               2        5        9        7        9       12
# 77 YrSold            2008     2007     2008     2006     2008     2009
# 78 SaleType            WD       WD       WD       WD       WD       WD
# 79 SaleCondition   Normal   Normal   Normal  Abnorml   Normal   Normal
# 80 SalePrice       208500   181500   223500   150000   127500   178000
#
# id                   953      972      1239     1458     1459     1460
#    variable
# 1  MSSubClass          85      160       20       70       20       20
# 2  MSZoning            RL       RL       RL       RL       RL       RL
# 3  LotFrontage       60.0     36.0     63.0     66.0     68.0     75.0
# 4  LotArea           7200     2268    13072     9042     9717     9937
# 5  Street            Pave     Pave     Pave     Pave     Pave     Pave
# 6  Alley              NaN      NaN      NaN      NaN      NaN      NaN
# 7  LotShape           Reg      Reg      Reg      Reg      Reg      Reg
# 8  LandContour        Lvl      Lvl      Lvl      Lvl      Lvl      Lvl
# 9  Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# 10 LotConfig       Inside   Inside   Inside   Inside   Inside   Inside
# 11 LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl      Gtl
# 12 Neighborhood   CollgCr  NridgHt  SawyerW  Crawfor    NAmes  Edwards
# 13 Condition1        Norm     Norm     RRAe     Norm     Norm     Norm
# 14 Condition2        Norm     Norm     Norm     Norm     Norm     Norm
# 15 BldgType          1Fam    Twnhs     1Fam     1Fam     1Fam     1Fam
# 16 HouseStyle      SFoyer   2Story   1Story   2Story   1Story   1Story
# 17 OverallQual          5        7        6        7        5        5
# 18 OverallCond          8        5        5        9        6        6
# 19 YearBuilt         1972     2003     2005     1941     1950     1965
# 20 YearRemodAdd      2003     2004     2005     2006     1996     1965
# 21 RoofStyle        Gable    Gable    Gable    Gable      Hip    Gable
# 22 RoofMatl       CompShg  CompShg  CompShg  CompShg  CompShg  CompShg
# 23 Exterior1st    WdShing  VinylSd  VinylSd  CemntBd  MetalSd  HdBoard
# 24 Exterior2nd    HdBoard  Wd Shng  VinylSd  CmentBd  MetalSd  HdBoard
# 25 MasVnrType        None    Stone     None     None     None     None
# 26 MasVnrArea         0.0    106.0      0.0      0.0      0.0      0.0
# 27 ExterQual           TA       Gd       Gd       Ex       TA       Gd
# 28 ExterCond           Gd       TA       TA       Gd       TA       TA
# 29 Foundation      CBlock    PConc    PConc    Stone   CBlock   CBlock
# 30 BsmtQual            Gd       Gd       Gd       TA       TA       TA
# 31 BsmtCond            TA       TA       TA       Gd       TA       TA
# 32 BsmtExposure        Av       No       No       No       Mn       No
# 33 BsmtFinType1       GLQ      GLQ      Unf      GLQ      GLQ      BLQ
# 34 BsmtFinSF1         660      567        0      275       49      830
# 35 BsmtFinType2       Unf      Unf      Unf      Unf      Rec      LwQ
# 36 BsmtFinSF2           0        0        0        0     1029      290
# 37 BsmtUnfSF          108      197     1141      877        0      136
# 38 TotalBsmtSF        768      764     1141     1152     1078     1256
# 39 Heating           GasA     GasA     GasA     GasA     GasA     GasA
# 40 HeatingQC           Gd       Ex       Ex       Ex       Gd       Gd
# 41 CentralAir           Y        Y        Y        Y        Y        Y
# 42 Electrical       SBrkr    SBrkr    SBrkr    SBrkr    FuseA    SBrkr
# 43 1stFlrSF           768      764     1141     1188     1078     1256
# 44 2ndFlrSF             0      862        0     1152        0        0
# 45 LowQualFinSF         0        0        0        0        0        0
# 46 GrLivArea          768     1626     1141     2340     1078     1256
# 47 BsmtFullBath         0        0        0        0        1        1
# 48 BsmtHalfBath         1        0        0        0        0        0
# 49 FullBath             1        2        1        2        1        1
# 50 HalfBath             0        0        1        0        0        1
# 51 BedroomAbvGr         2        2        3        4        2        3
# 52 KitchenAbvGr         1        1        1        1        1        1
# 53 KitchenQual         TA       Gd       TA       Gd       Gd       TA
# 54 TotRmsAbvGrd         5        6        6        9        5        6
# 55 Functional         Typ      Typ      Typ      Typ      Typ      Typ
# 56 Fireplaces           0        0        0        2        0        0
# 57 FireplaceQu        NaN      NaN      NaN       Gd      NaN      NaN
# 58 GarageType      Detchd  BuiltIn   Detchd   Attchd   Attchd   Attchd
# 59 GarageYrBlt     1974.0   2003.0   2005.0   1941.0   1950.0   1965.0
# 60 GarageFinish       Fin      RFn      Unf      RFn      Unf      Fin
# 61 GarageCars           1        2        2        1        1        1
# 62 GarageArea         396      474      484      252      240      276
# 63 GarageQual          TA       TA       TA       TA       TA       TA
# 64 GarageCond          TA       TA       TA       TA       TA       TA
# 65 PavedDrive           Y        Y        Y        Y        Y        Y
# 66 WoodDeckSF         192        0        0        0      366      736
# 67 OpenPorchSF          0       27        0       60        0       68
# 68 EnclosedPorch        0        0        0        0      112        0
# 69 3SsnPorch            0        0        0        0        0        0
# 70 ScreenPorch          0        0        0        0        0        0
# 71 PoolArea             0        0        0        0        0        0
# 72 PoolQC             NaN      NaN      NaN      NaN      NaN      NaN
# 73 Fence            MnPrv      NaN      NaN    GdPrv      NaN      NaN
# 74 MiscFeature        NaN      NaN      NaN     Shed      NaN      NaN
# 75 MiscVal              0        0        0     2500        0        0
# 76 MoSold               4        7        3        5        4        6
# 77 YrSold            2009     2009     2006     2010     2010     2008
# 78 SaleType            WD       WD       WD       WD       WD       WD
# 79 SaleCondition   Normal   Normal  Abnorml   Normal   Normal   Normal
# 80 SalePrice       133900   173000   142500   266500   142125   147500

# %%
reset_option('display.*')
